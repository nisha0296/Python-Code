# %% [markdown]
# <a href="https://colab.research.google.com/github/nisha0296/Python-Code/blob/main/MoviesDataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import requests

# %%
response=requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=a553f1b225529cdfe1b394f68188ea6d&language=en-US&page=1")

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/ejniJnlOdtSgtbh8D7u2RxT6Uli.jpg',
#    'genre_ids': [35, 14],
#    'id': 772071,
#    'original_language': 'es',
#    'original_title': 'Cuando Sea Joven',
#    'overview': '70-year-old Malena gets a second chance at life when she magically turns into her 22-year-old self. Now, posing as "Maria" to hide her true identity, she becomes the lead singer of her grandson\'s band and tries to recover her dream of singing, which she had to give up at some point.',
#    'popularity': 50.034,
#    'poster_path': '/6gIJuFHh5Lj4dNaPG3TzIMl7L68.jpg',
#    'release_date': '2022-09-14',
#    'title': 'Cuando Sea Joven',
#    'video': False,
#    'vote_average': 8.8,
#    'vote_count': 203},
#   {'adult': False,
#    'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#    'genre_ids': [18, 80],
#    'id': 238,
#    'original_language': 'en',
#    'original_title': 'The Godfather',
# ...

# %%
data=pd.DataFrame(response.json()['results'])

# %%
data.head()[['id','popularity','title','overview']]
# Out:
#        id  popularity                                     title  \
# 0  772071      50.034                          Cuando Sea Joven
# 1     238      85.071                             The Godfather
# 2     278      67.991                  The Shawshank Redemption
# 3  995133      47.245  The Boy, the Mole, the Fox and the Horse
# 4     240      54.053                     The Godfather Part II
#
#                                             overview
# 0  70-year-old Malena gets a second chance at lif...
# 1  Spanning the years 1945 to 1955, a chronicle o...
# 2  Framed in the 1940s for the double murder of h...
# 3  The unlikely friendship of a boy, a mole, a fo...
# 4  In the continuing saga of the Corleone crime f...

# %%
df=pd.DataFrame()

# %%
for i in range(1,429):
  response=requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=a553f1b225529cdfe1b394f68188ea6d&language=en-US&page={}".format(i))
  temp_df=pd.DataFrame(response.json()['results'])[['id','popularity','title','overview']]
  df=df.append(temp_df,ignore_index=True)

# %%
df.to_csv('movies.csv')
